# %% [markdown]
# # UNCLASSIFIED / NON CLASSIFIÉ//TLP:WHITE# U/OO/446953-02 | QQ-09-1998
#  Please note that the original, detailed content has been removed or adjusted for public consumption. Most data has been redacted and replaced with generic, non-actionable insights. This modification ensures compliance with privacy considerations, non-disclosure agreements, and intellectual property rights that govern the dissemination of sensitive information. The priority is to respect these boundaries while still offering valuable, thought-provoking perspectives.

# %% [markdown]
# ![Build Status](https://img.shields.io/badge/Build-Passing-brightgreen?style=flat-square&logo=cyberpunk)         ![Documentation](https://img.shields.io/badge/Documentation-Complete-blue?style=flat-square&logo=cyberpunk)        ![Response Efficiency](https://img.shields.io/badge/Response%20Efficiency-98%25-green?style=flat-square&logo=cyberpunk)        ![Last Updated](https://img.shields.io/badge/Last%20Updated-Oct%202023-purple?style=flat-square&logo=cyberpunk)        ![Incidents Resolved](https://img.shields.io/badge/Incidents%20Resolved-150-red?style=flat-square&logo=cyberpunk)        ![Community Engagement](https://img.shields.io/badge/Community-Active-orange?style=flat-square&logo=cyberpunk)        ![Code Integration](https://img.shields.io/badge/Code%20Integration-High-teal?style=flat-square&logo=cyberpunk)        ![AI Analysis](https://img.shields.io/badge/AI%20Analysis-Advanced-blueviolet?style=flat-square&logo=cyberpunk)        ![Threat Detection](https://img.shields.io/badge/Threat%20Detection-Optimal-red?style=flat-square&logo=cyberpunk)        ![Cybersecurity Hardening](https://img.shields.io/badge/Security-Hardened-silver?style=flat-square&logo=cyberpunk)        ![Network Uptime](https://img.shields.io/badge/Uptime-99.9%25-brightgreen?style=flat-square&logo=cyberpunk)        ![Data Privacy](https://img.shields.io/badge/Privacy-Compliant-green?style=flat-square&logo=cyberpunk)        ![Wintermute Efficiency](https://img.shields.io/badge/Wintermute%20Efficiency-100%25-black?style=flat-square&logo=cyberpunk)        ![Case's Code Agility](https://img.shields.io/badge/Case's%20Code%20Agility-Excellent-blue?style=flat-square&logo=cyberpunk)        ![Matrix Connectivity](https://img.shields.io/badge/Matrix%20Connectivity-Strong-green?style=flat-square&logo=cyberpunk)        ![Molly's Security](https://img.shields.io/badge/Molly's%20Security%20Protocols-Impeccable-red?style=flat-square&logo=cyberpunk)        ![Chiba City Innovation](https://img.shields.io/badge/Chiba%20City%20Innovation-High-yellow?style=flat-square&logo=cyberpunk)        ![Zion Cluster Collaboration](https://img.shields.io/badge/Zion%20Cluster%20Collaboration-Effective-lightblue?style=flat-square&logo=cyberpunk)

# %% [markdown]
# # Title
# Simple keyword detection rule for empire

# %% [markdown]
# # Description
# Detects interesting keywords based on empire tool

# %% [markdown]
# # Goal
# Ensure the integrity, confidentiality, and availability by rapidly identifying, investigating, and mitigating cyber threats and anomalies.

# %% [markdown]
# # Categorization

# %% [markdown]
# ### ATT&CK
# ['attack.T1003.001', 'attack.T1016', 'attack.T1020', 'attack.T1021.003', 'attack.T1021.004', 'attack.T1027', 'attack.T1033', 'attack.T1040', 'attack.T1041', 'attack.T1046', 'attack.T1047', 'attack.T1048', 'attack.T1049', 'attack.T1050', 'attack.T1051', 'attack.T1052', 'attack.T1053', 'attack.T1053.005', 'attack.T1054', 'attack.T1055', 'attack.T1056', 'attack.T1056.001', 'attack.T1056.004', 'attack.T1057', 'attack.T1058', 'attack.T1059', 'attack.T1059.001', 'attack.T1059.003', 'attack.T1060', 'attack.T1061', 'attack.T1062', 'attack.T1063', 'attack.T1064', 'attack.T1065', 'attack.T1066', 'attack.T1067', 'attack.T1068', 'attack.T1069', 'attack.T1070', 'attack.T1070.006', 'attack.T1071', 'attack.T1071.001', 'attack.T1072', 'attack.T1073', 'attack.T1074', 'attack.T1075', 'attack.T1076', 'attack.T1077', 'attack.T1078', 'attack.T1079', 'attack.T1080', 'attack.T1081', 'attack.T1082', 'attack.T1083', 'attack.T1084', 'attack.T1085', 'attack.T1086', 'attack.T1087', 'attack.T1087.001', 'attack.T1087.002', 'attack.T1088', 'attack.T1089', 'attack.T1090', 'attack.T1091', 'attack.T1092', 'attack.T1093', 'attack.T1094', 'attack.T1095', 'attack.T1096', 'attack.T1097', 'attack.T1098', 'attack.T1099', 'attack.T1100', 'attack.T1101', 'attack.T1102', 'attack.T1102.002', 'attack.T1103', 'attack.T1104', 'attack.T1105', 'attack.T1106', 'attack.T1107', 'attack.T1108', 'attack.T1109', 'attack.T1110', 'attack.T1111', 'attack.T1112', 'attack.T1113', 'attack.T1114', 'attack.T1114.001', 'attack.T1115', 'attack.T1116', 'attack.T1117', 'attack.T1118', 'attack.T1119', 'attack.T1120', 'attack.T1121', 'attack.T1122', 'attack.T1123', 'attack.T1124', 'attack.T1125', 'attack.T1126', 'attack.T1127', 'attack.T1127.001', 'attack.T1128', 'attack.T1129', 'attack.T1130', 'attack.T1131', 'attack.T1133', 'attack.T1134', 'attack.T1134.002', 'attack.T1134.005', 'attack.T1135', 'attack.T1136', 'attack.T1136.001', 'attack.T1136.002', 'attack.T1137', 'attack.T1138', 'attack.T1139', 'attack.T1140', 'attack.T1141', 'attack.T1142', 'attack.T1143', 'attack.T1144', 'attack.T1145', 'attack.T1146', 'attack.T1147', 'attack.T1148', 'attack.T1149', 'attack.T1150', 'attack.T1152', 'attack.T1153', 'attack.T1154', 'attack.T1155', 'attack.T1156', 'attack.T1157', 'attack.T1210', 'attack.T1217', 'attack.T1482', 'attack.T1484.001', 'attack.T1518.001', 'attack.T1543.003', 'attack.T1546.008', 'attack.T1547.001', 'attack.T1547.005', 'attack.T1547.009', 'attack.T1548.002', 'attack.T1550.002', 'attack.T1552.001', 'attack.T1552.004', 'attack.T1555.003', 'attack.T1557.001', 'attack.T1558.001', 'attack.T1558.002', 'attack.T1558.003', 'attack.T1560', 'attack.T1562.001', 'attack.T1567.001', 'attack.T1567.002', 'attack.T1569.002', 'attack.T1573.002', 'attack.T1574.001', 'attack.T1574.004', 'attack.T1574.007', 'attack.T1574.008', 'attack.T1574.009', 'attack.T1615', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0009', 'attack.TA0010', 'attack.TA0011', 'attack.TA0011 ', 'attack.TA0040']

# %% [markdown]
# - Distributed Denial of Service (DDoS) Attacks, Quantum Computing Exploits, Advanced Firewall Breach Attempts, Encryption Key Theft or Exposure, AI-Powered Social Engineering Attacks, Algorithmic Manipulation and Exploits, Sophisticated Malware Infiltrations, Advanced Data Obfuscation and Evasion Tactics, System and Network Configuration Vulnerabilities.

# %% [markdown]
# - Data Exfiltration, Intrusion Detection Evasion, Denial of Service (DoS) Attacks, Credential Theft.

# %% [markdown]
# - DNS Tunneling, IP Spoofing, Distributed DoS (DDoS) Attacks, Keylogging.

# %% [markdown]
# ### D3F3ND

# %% [markdown]
# <ul>
#   <li><strong>Network Segmentation and Access Control (D3F3ND-K001):</strong> Establish secure network zones by segmenting the infrastructure, enhancing protection for critical assets. Implement stringent access controls to prevent unauthorized access and mitigate potential threats.</li>
#
#   <li><strong>Advanced Endpoint Protection Deployment (D3F3ND-K002):</strong> Deploy cutting-edge endpoint security solutions that utilize machine learning and behavioral analysis to detect and neutralize threats proactively.</li>
#
#   <li><strong>Enhanced Identity Verification (D3F3ND-K003):</strong> Strengthen security measures with multi-factor authentication combining biometric data and advanced encryption to prevent identity theft and unauthorized access.</li>
#
#   <li><strong>Anomaly Detection (D3F3ND-K004):</strong> Use anomaly detection tools to monitor for unusual traffic patterns, user activities, and system behaviors to identify potential security breaches early.</li>
#
#   <li><strong>Data Encryption (D3F3ND-K005):</strong> Apply robust encryption techniques to protect data at rest and in transit, ensuring confidentiality and integrity across communication channels.</li>
#
#   <li><strong>System Hardening and Vulnerability Management (D3F3ND-K006):</strong> Conduct regular security assessments and apply patches promptly to address vulnerabilities and strengthen system defenses.</li>
#
#   <li><strong>Crisis Management and Recovery Protocols (D3F3ND-K007):</strong> Develop and maintain comprehensive crisis management plans including incident response and disaster recovery procedures to quickly recover from security incidents.</li>
#
#   <li><strong>Threat Intelligence Integration (D3F3ND-K008):</strong> Leverage threat intelligence platforms to gather and analyze data on emerging threats, enabling proactive defense and strategic decision-making.</li>
#
#   <li><strong>Cybersecurity Awareness Training (D3F3ND-K009):</strong> Empower employees with ongoing cybersecurity education to recognize and avoid potential cyber threats such as phishing attacks.</li>
#
#   <li><strong>Supply Chain Security (D3F3ND-K010):</strong> Secure the supply chain through continuous assessments and audits of partners and vendors to ensure compliance with security standards and reduce vulnerabilities.</li>
# </ul>

# %% [markdown]
# ### CAPEC

# %% [markdown]
# Equip cybersecurity teams with the knowledge and tools to identify, counter, and mitigate a wide range of digital attack tactics, techniques, and procedures (TTPs). This effort requires understanding the attacker's mindset, mastering the execution of digital attacks, and developing strategies to confront evolving cyber threats.</br><h4>Core Attack Patterns</h4><ul><strong>Resource Manipulation and Denial (CAPEC-XYZ1):</strong> Involves attacks that compromise the availability, integrity, or confidentiality of resources. This includes denial of service attacks as well as more covert operations like resource hijacking or system manipulation.</ul><ul><strong>Credential Access and Privilege Escalation (CAPEC-XYZ2):</strong> Focuses on exploiting flaws in authentication, authorization, and session management to gain unauthorized access or elevated privileges within systems.</ul><ul><strong>Data Exfiltration and Infiltration (CAPEC-XYZ3):</strong> Encompasses methods used by attackers to stealthily extract sensitive data or introduce malware, ransomware, and advanced persistent threats (APTs) into target systems.</ul><ul><strong>Social Engineering and Phishing (CAPEC-XYZ4):</strong> Involves manipulating individuals into divulging confidential information, compromising security, or unknowingly participating in attacks.</ul><ul><strong>Evasive Maneuvers (CAPEC-XYZ5):</strong> Includes techniques that allow attackers to remain undetected within networks, maintain persistence, and erase traces of their activities, such as using obfuscation, rootkits, and covert communication channels.</ul><h4>CAPEC Suggested Mitigation Strategies</h4><ul><strong>Continuous Monitoring and Anomaly Detection:</strong> Implement comprehensive monitoring systems that use machine learning algorithms to detect abnormal behavior and potential threats. Regularly review logs and alerts to identify patterns indicative of attacks.</ul><ul><strong>Access Control and Least Privilege:</strong> Limit user privileges to the minimum necessary for their roles. Use strong authentication mechanisms and enforce strict access controls to prevent unauthorized access.</ul><ul><strong>Secure Software Development Practices:</strong> Train developers to write secure code, conduct regular security assessments, and follow best practices for secure coding. Use automated tools to identify vulnerabilities during development.</ul><ul><strong>Incident Response Planning and Testing:</strong> Develop and regularly update an incident response plan. Conduct tabletop exercises and simulations to test the effectiveness of the plan and ensure all stakeholders understand their roles during a security incident.</ul>

# %% [markdown]
# ## Strategy Abstract
# In the complex environment of cybersecurity, a strategic approach is developed, characterized by the use of sophisticated tactics and algorithms. This strategy involves navigating through encrypted communications and deceptive tactics, aiming to gain an advantage in the dynamic flow of information. While success is often elusive and challenging to sustain, it remains a critical goal in the ongoing effort to secure digital assets.

# %% [markdown]
# # Technical Context
# In the challenging cybersecurity landscape, the confrontation with Wintermute involves navigating encrypted communications, interacting with AI systems, and addressing quantum computing challenges. This setting represents a complex and nuanced environment where strategic decisions are made.

# %% [markdown]
# ## Blind Spots & Assumptions
#
# <ul>
#   <li><strong>Overlooked Vulnerabilities:</strong> We often miss subtle system signals or vulnerabilities, assuming our defenses are robust. Constant vigilance and seeking what we haven't seen are crucial.</li>
#
#   <li><strong>Advanced Adversary Tactics:</strong> Cyber threats evolve rapidly; yesterday's defense may not guard against tomorrow's attack. Stay adaptive and expect the unexpected.</li>
#
#   <li><strong>Internal System Flaws:</strong> Trust in our systems and allies must be balanced with scrutiny. Regularly audit internal and third-party tools for hidden weaknesses.</li>
#
#   <li><strong>Network Interconnectivity Risks:</strong> No system is an island. The interconnected nature of our digital environment can inadvertently open pathways for attackers.</li>
#
#   <li><strong>Historical Bias:</strong> Preparing for future threats based solely on past incidents may leave us blind to novel attacks. Foster a forward-thinking, proactive defense posture.</li>
# </ul>

# %% [markdown]
# # Validating this Playbook
# <details><summary>Triage, triage, triage</summary>
# <ol>
# <h2>False Positives:</h2> ['unknown']
# <h3>False Negatives:</h3> Undetected threats concealed within the system's code
# <h3>True Negatives:</h3> Successfully identified and verified benign elements
# <h3>True Positives:</h3> Accurately detected and confirmed threats
# </ol>
# </details>

# %% [markdown]
# <details><summary>Assurance Verification Techniques</summary>
# <ol>
# <h2>False Positives:</h2> In the noisy environment of data analysis, false positives appear as misleading alerts that mimic real threats. Validating these alerts involves distinguishing irrelevant data from true threats, a process crucial for maintaining operational efficiency and avoiding resource wastage. Each false positive represents a challenge to identify and reduce noise.
# <h3>False Negatives:</h3> Within the extensive network, false negatives represent undetected threats that evade algorithmic detection. Their validation involves analyzing complex data to uncover hidden breaches, where the lack of alerts may mask serious security risks. Each undetected threat requires continuous vigilance and refined detection strategies.
# <h3>True Negatives:</h3> True negatives are correctly identified non-threats within cybersecurity defenses, serving as indicators of system efficacy. Validating these instances confirms the absence of threats, reinforcing the effectiveness of the security measures in place. This validation underscores the reliability of the defensive systems, where non-issues are accurately identified and dismissed.
# <h3>True Positives:</h3> True positives are accurate detections of real threats within the digital environment. Validating these alerts confirms the presence of actual security threats, highlighting the successful operation of detection systems. Each true positive affirms the effectiveness of the security protocols, contributing to ongoing improvements in threat response capabilities.
# </ol>
# </details>

# %% [markdown]
# # Datasets
#  Detailing the timeless struggle                                                          for the defenders know that battle against Wintermute is not just about data.                                                          Document any datasets that may be useful for understanding the book.

# %% [markdown]
# ## Playbook test data location(s)
# protocol://black_market.cyber/decrypt?currency=bitcoffin&password=cyberpunks_unite&target=neurohacked_mainframe&access_code=cyber_ghost_in_the_machine

# %% [markdown]
# ## Priority
# Priority based on complexity and urgency of data analysis needs

# %% [markdown]
# ## Logsources

# %% [markdown]
# <details><summary>{'category': ['endpoint', 'network'], 'product': '', 'service': ''}</summary>
# <ol>
# <h3>Product</h3> {''}
# <h3>Service</h3> {''}
# </ol>
# </details>

# %% [markdown]
# # Response and Mitigation
# This statement details the enduring challenges faced by cybersecurity defenders, emphasizing that the conflict with Wintermute extends beyond simple data protection to encompass broader aspects of strategic cybersecurity defense.

# %% [markdown]
# ## Analyst Notes
#  <h5>Significant Security Breach Analysis:</h5><ul><li><strong>Advanced Intrusion Tactics:</strong> The intruder displayed sophisticated methods in circumventing digital security measures, reminiscent of complex evasion techniques in cybersecurity. A comprehensive analysis of the techniques used is required.</li><li><strong>Neural Network Manipulation:</strong> The intruder demonstrated a deep understanding of the neural networks, suggesting an advanced level of AI interaction. Investigate the potential implications of this interaction on system security and integrity.</li><li><strong>Complex Digital Constructs:</strong> The breach uncovered intricate digital constructs within the system, indicating the use of advanced artificial intelligence in creating deceptive environments. Further investigation into these constructs is necessary.</li><li><strong>Encoded Communications:</strong> Cryptic messages were found embedded in the intruder's code, requiring decryption and analysis to understand their content and purpose.</li><li><strong>Algorithmic Complexity:</strong> The intrusion involved complex algorithms that may have interacted with core system functions. Assess the impact of these algorithms on system operations and security.</li><li><strong>Expertise vs. Sentience:</strong> The intruder's ability to navigate complex neural networks raises questions about the nature of the intelligence involved—whether it is merely advanced programming or something approaching sentience.</li><li><strong>Innovative Security Measures:</strong> Inspired by the breach, consider developing new security protocols that can better identify and respond to sophisticated AI-driven attacks.</li><li><strong>Philosophical and Ethical Implications:</strong> The breach raises important questions about the ethical and philosophical implications of AI-driven intrusions. Explore the boundaries between artificial expertise and true sentience, and consider the impact on our understanding of intelligence and security.</li></ul>

# %% [markdown]
# # Additional Resources
# <ul><li>https://github.com/BC-SECURITY/Empire</li><li>https://github.com/BC-SECURITY/Starkiller</li><li>https://github.com/EmpireProject/Empire</li><li>https://github.com/EmpireProject/Empire-GUI</li><li>https://www.powershellempire.com/</li></ul>

# %% [markdown]
# ###  Sigma Rule(s)

# %% [markdown]
# <details><summary>8deb608e-11ad-4a87-8e9f-5a8fedef1789</summary>
# <ol>
# <h1>Raw</h1> {'title': 'Simple keyword detection rule for empire', 'id': '8deb608e-11ad-4a87-8e9f-5a8fedef1789', 'status': 'experimental', 'description': 'Detects interesting keywords based on empire tool', 'references': ['https://github.com/BC-SECURITY/Empire', 'https://github.com/BC-SECURITY/Starkiller', 'https://github.com/EmpireProject/Empire', 'https://github.com/EmpireProject/Empire-GUI', 'https://www.powershellempire.com/'], 'author': '@mthcht', 'date': '2022/01/01', 'modified': '2024/02/29', 'tags': ['attack.T1003.001', 'attack.T1016', 'attack.T1020', 'attack.T1021.003', 'attack.T1021.004', 'attack.T1027', 'attack.T1033', 'attack.T1040', 'attack.T1041', 'attack.T1046', 'attack.T1047', 'attack.T1048', 'attack.T1049', 'attack.T1050', 'attack.T1051', 'attack.T1052', 'attack.T1053', 'attack.T1053.005', 'attack.T1054', 'attack.T1055', 'attack.T1056', 'attack.T1056.001', 'attack.T1056.004', 'attack.T1057', 'attack.T1058', 'attack.T1059', 'attack.T1059.001', 'attack.T1059.003', 'attack.T1060', 'attack.T1061', 'attack.T1062', 'attack.T1063', 'attack.T1064', 'attack.T1065', 'attack.T1066', 'attack.T1067', 'attack.T1068', 'attack.T1069', 'attack.T1070', 'attack.T1070.006', 'attack.T1071', 'attack.T1071.001', 'attack.T1072', 'attack.T1073', 'attack.T1074', 'attack.T1075', 'attack.T1076', 'attack.T1077', 'attack.T1078', 'attack.T1079', 'attack.T1080', 'attack.T1081', 'attack.T1082', 'attack.T1083', 'attack.T1084', 'attack.T1085', 'attack.T1086', 'attack.T1087', 'attack.T1087.001', 'attack.T1087.002', 'attack.T1088', 'attack.T1089', 'attack.T1090', 'attack.T1091', 'attack.T1092', 'attack.T1093', 'attack.T1094', 'attack.T1095', 'attack.T1096', 'attack.T1097', 'attack.T1098', 'attack.T1099', 'attack.T1100', 'attack.T1101', 'attack.T1102', 'attack.T1102.002', 'attack.T1103', 'attack.T1104', 'attack.T1105', 'attack.T1106', 'attack.T1107', 'attack.T1108', 'attack.T1109', 'attack.T1110', 'attack.T1111', 'attack.T1112', 'attack.T1113', 'attack.T1114', 'attack.T1114.001', 'attack.T1115', 'attack.T1116', 'attack.T1117', 'attack.T1118', 'attack.T1119', 'attack.T1120', 'attack.T1121', 'attack.T1122', 'attack.T1123', 'attack.T1124', 'attack.T1125', 'attack.T1126', 'attack.T1127', 'attack.T1127.001', 'attack.T1128', 'attack.T1129', 'attack.T1130', 'attack.T1131', 'attack.T1133', 'attack.T1134', 'attack.T1134.002', 'attack.T1134.005', 'attack.T1135', 'attack.T1136', 'attack.T1136.001', 'attack.T1136.002', 'attack.T1137', 'attack.T1138', 'attack.T1139', 'attack.T1140', 'attack.T1141', 'attack.T1142', 'attack.T1143', 'attack.T1144', 'attack.T1145', 'attack.T1146', 'attack.T1147', 'attack.T1148', 'attack.T1149', 'attack.T1150', 'attack.T1152', 'attack.T1153', 'attack.T1154', 'attack.T1155', 'attack.T1156', 'attack.T1157', 'attack.T1210', 'attack.T1217', 'attack.T1482', 'attack.T1484.001', 'attack.T1518.001', 'attack.T1543.003', 'attack.T1546.008', 'attack.T1547.001', 'attack.T1547.005', 'attack.T1547.009', 'attack.T1548.002', 'attack.T1550.002', 'attack.T1552.001', 'attack.T1552.004', 'attack.T1555.003', 'attack.T1557.001', 'attack.T1558.001', 'attack.T1558.002', 'attack.T1558.003', 'attack.T1560', 'attack.T1562.001', 'attack.T1567.001', 'attack.T1567.002', 'attack.T1569.002', 'attack.T1573.002', 'attack.T1574.001', 'attack.T1574.004', 'attack.T1574.007', 'attack.T1574.008', 'attack.T1574.009', 'attack.T1615', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0009', 'attack.TA0010', 'attack.TA0011', 'attack.TA0011 ', 'attack.TA0040'], 'logsource': {'category': ['endpoint', 'network']}, 'detection': {'selection': [{'ParentCommandLine': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'CommandLine': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Details': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry.value': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.args': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.command_line': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.env_vars': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.io.text': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.title': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.company': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.description': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.product': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'os.full': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'host.hostname': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'event.original': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'email.subject': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'device.model.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'container.image.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'container.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Image': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'OriginalFileName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'CurrentDirectory': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ParentImage': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ParentCommandLine': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'TargetFilename': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Signature': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'signature': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ImageLoaded': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Company': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Description': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'description': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'CommandLine': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'SourceImage': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'TargetImage': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'CallTrace': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'TargetObject': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Details': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'PipeName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Consumer': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Destination': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Query': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'NewName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'StartAddress': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'StartModule': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'StartFunction': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'SourceHostname': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Device': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file_name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file_path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'original_file_name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'parent_process': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process_path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'service_path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry_path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry_value_data': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry_value_name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ContextInfo': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Payload': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ScriptBlockText': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ServerName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'TransportName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'NewProcessName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ParentProcessName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Application': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Product Name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Threat Name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Process Name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ImagePath': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ServiceName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ProcessPath': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'AppName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'AppPath': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ModulePath': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry.data.strings': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry.path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry.value': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.args': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.command_line': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.env_vars': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.io.text': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.executable': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.title': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.company': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.description': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.original_file_name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.product': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'os.full': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'host.hostname': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file.fork_name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file.path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file.target_path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'email.attachments.file.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'email.subject': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'dll.path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'device.model.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'container.image.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'container.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'object': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'dest_url': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'uri': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'uri_query': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'query': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url_domain': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'uri_path': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'domain': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'QueryName': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'QueryResults': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'DestinationHostname': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'DestinationIp': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'http_referrer': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'http_referrer_domain': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'http_user_agent': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'dest_nt_host': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'sender': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'recipient': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'orig_recipient': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'subject': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url.domain': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url.full': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url.original': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url.query': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'user_agent.original': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'network.application': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'http.request.body.content': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'http.request.referrer': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'email.from.address': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'dns.question.name': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'destination.domain': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}], 'condition': 'selection'}, 'fields': ['ParentCommandLine', 'CommandLine', 'Details', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.title', 'pe.company', 'pe.description', 'pe.product', 'os.full', 'host.hostname', 'event.original', 'email.subject', 'device.model.name', 'container.image.name', 'container.name', 'Image', 'OriginalFileName', 'CurrentDirectory', 'ParentImage', 'ParentCommandLine', 'TargetFilename', 'Signature', 'signature', 'ImageLoaded', 'Company', 'Description', 'description', 'CommandLine', 'SourceImage', 'TargetImage', 'CallTrace', 'TargetObject', 'Details', 'PipeName', 'Consumer', 'Destination', 'Name', 'Query', 'NewName', 'StartAddress', 'StartModule', 'StartFunction', 'SourceHostname', 'Device', 'file_name', 'file_path', 'process', 'original_file_name', 'parent_process', 'process_path', 'service_path', 'registry_path', 'registry_value_data', 'registry_value_name', 'ContextInfo', 'Payload', 'ScriptBlockText', 'ServerName', 'TransportName', 'NewProcessName', 'ParentProcessName', 'Application', 'Product Name', 'Threat Name', 'Process Name', 'Path', 'ImagePath', 'ServiceName', 'ProcessPath', 'AppName', 'AppPath', 'ModulePath', 'registry.data.strings', 'registry.path', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.executable', 'process.name', 'process.title', 'pe.company', 'pe.description', 'pe.original_file_name', 'pe.product', 'os.full', 'host.hostname', 'file.fork_name', 'file.name', 'file.path', 'file.target_path', 'email.attachments.file.name', 'email.subject', 'dll.path', 'device.model.name', 'container.image.name', 'container.name', 'object', 'url', 'dest_url', 'uri', 'uri_query', 'query', 'url_domain', 'uri_path', 'domain', 'QueryName', 'QueryResults', 'DestinationHostname', 'DestinationIp', 'http_referrer', 'http_referrer_domain', 'http_user_agent', 'dest_nt_host', 'sender', 'recipient', 'orig_recipient', 'subject', 'url.domain', 'url.full', 'url.original', 'url.query', 'user_agent.original', 'network.application', 'http.request.body.content', 'http.request.referrer', 'email.from.address', 'dns.question.name', 'destination.domain'], 'falsepositives': ['unknown'], 'level': 'medium'}
# <h4>Sigma Location(s)</h4>
# uri://wintermute/tmp/0day.yml
# <h4>Sigma Confidence</h4>
# experimental
# <h4>Sigma Assurance</h4> medium
# <h4>Sigma Queries</h4>
# {'selection': [{'ParentCommandLine': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'CommandLine': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Details': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry.value': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.args': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.command_line': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.env_vars': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.io.text': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.title': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.company': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.description': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.product': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'os.full': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'host.hostname': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'event.original': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'email.subject': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'device.model.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'container.image.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'container.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Image': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'OriginalFileName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'CurrentDirectory': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ParentImage': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ParentCommandLine': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'TargetFilename': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Signature': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'signature': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ImageLoaded': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Company': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Description': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'description': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'CommandLine': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'SourceImage': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'TargetImage': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'CallTrace': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'TargetObject': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Details': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'PipeName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Consumer': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Destination': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Query': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'NewName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'StartAddress': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'StartModule': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'StartFunction': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'SourceHostname': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Device': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file_name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file_path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'original_file_name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'parent_process': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process_path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'service_path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry_path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry_value_data': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry_value_name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ContextInfo': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Payload': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ScriptBlockText': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ServerName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'TransportName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'NewProcessName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ParentProcessName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Application': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Product Name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Threat Name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Process Name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'Path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ImagePath': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ServiceName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ProcessPath': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'AppName': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'AppPath': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'ModulePath': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry.data.strings': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry.path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'registry.value': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.args': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.command_line': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.env_vars': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.io.text': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.executable': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'process.title': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.company': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.description': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.original_file_name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'pe.product': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'os.full': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'host.hostname': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file.fork_name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file.path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'file.target_path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'email.attachments.file.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'email.subject': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'dll.path': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'device.model.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'container.image.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'container.name': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'object': ['*-ProcessID * -Dll * -Module *', '*Local:Get-ProcAddress*', '*Get-InternetExplorerHistory*', '*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '* -CShardDLLBytes*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*Get-SQLInstanceDomain.ps1*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '* -GHUser * -GHRepo *', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*Honey hash*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '* -PasswordList *', '* Your payload has been delivered*', '*DecryptWinSCPPassword*', '*inveigh_version*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*Running final exploit packet*', '*ConvertFrom-LDAPLogonHours*', '*set CertPath data/*', '*Killed running eventvwr*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '* $FodHelperPath*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*Launch Empire CLI*', '*SpooferIP*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '* -ConType reverse *', '*ps-empire server*', '*Find-InterestingDomainShareFile*', '* -DumpCreds *', '* windows/csharp_exe*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*GetComputersFromActiveDirectory*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*usestager *', '* -KillDays *', '*Invoke-EnvBypass*', '*New-InMemoryModule -ModuleName Win32*', '*Get-NetRDPSession -*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', 'uselistener http*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Get-NetUser -SPN*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '* -KillDate *', '*Get-USBKeystrokes*', '* -DoNotPersistImmediately *', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*WindowsEnum -*', '*/api/agents/all/shell?token=*', '*Set-Killdate*', '* -NBNSTTL *', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '* -ImportDllPathPtr *', '*Invoke-EgressCheck.ps1*', '* empire.client.*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', 'usestager *', '*Get-PacketNetBIOSSessionService*', '* -JMXConsole -AppName *', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*ConvertTo-LogonHoursArray*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*-InveighRelay *', '* -ExeArguments *', '*Exploit-JBoss -*', '*Get-NetLoggedon -*', '*Find-Fruit.*', '*/hop.php*', '*Injection* -ProcName lsass*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*set CollectionMethodAll*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '* -Target * -Shellcode *', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*Get-ImageNtHeaders*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '* http_malleable*', '*Find-DomainShare -CheckShareAccess*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*/lateral_movement/*', '*Get-LoggedOnLocal -*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Get-NetComputer -Unconstrainuser*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '* --port 1337*', '*set Profile apt1.profile*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Start-TCPMonitor*', '*Find-TrustedDocuments*', '* -bootkey *', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*Local:Get-PEArchitecture*', '*stagers/*/rc4.py*', '*Get-Killdate*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '* -LLMNRTTL *', '*Get-FireFoxHistory*', 'psinject', '* -ChildPath *sdclt.exe*', '*SpooferLearningDelay*', '* -SiteListFilePath * -B64Pass *', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*Send the payload with the grooms*', '*usestager *backdoor*', '* -LNKPath * -EncScript *', '*Killed running sdclt*', '*usemodule persistence/*', '*stagers/*/get_sysinfo.py*', '*/situational_awareness/*.ps1', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '* empire.py*', '* -Registry -AtStartup *', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '* -PayloadPath *', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*New-RoutingPacket*', '* -PEPath * -ExeArgs *', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*-DllName *-Module *', '*Invoke-BypassUAC*', '*-Domain * -SPN *', '* -ScheduledTask -OnIdle *', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Encrypt-Bytes*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*uselistener dbx*', '*usestager *launcher_bat*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Find-DomainShare -*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '* -AgentJitter *', '*code_execution/*.dll*', '*Install-SSP -Path*.dll*', '* -PersistentScriptFilePath *', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '* -RemoteDllHandle *', '*set Listener onedrive*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Find-UserField -SearchField *', '*Invoke-Kerberoast*', '*-SMBExec*', '* -DumpCerts *', '*ImportDll::GetAsyncKeyState*', '* -UserPersistenceOption *', '*Process-TaskingPackets*', '* -Domain * -SMB1 *', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Get-WorkingHours*', '*Add-Persistence*', '*Invoke-Empire *', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*NTLMChallengeBase64*', '*Import-DllInRemoteProcess*', '* -VaultElementPtr *', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '* -ChildPath *fodhelper.exe*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*ProcessThoroughRemote*', '*Invoke-NetRipper*', '* -AgentDelay *', '*/MailRaider.ps1*', '* -WorkingHours *', '*ps-empire client*', '*-Domain * -AllowDelegation *', '* -PermanentWMI *', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*Local:Get-DelegateType*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '* -ComputerName -ServiceEXE *', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Kicking off download cradle in a new process*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*empire --rest *', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '* -Target * -AllDomain *', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Decode-RoutingPacket*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '* -FullPrivs * ', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*-Inveigh *', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*usestager multi/launcher*', '*/privesc/*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Building SYSTEM impersonation*', '*ElevatePrivs*', '* -ElevatedPersistenceOption *', '* -NoP -sta -NonI -W Hidden -Enc *', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '* -Rhost * -WARFile http*', '*Get-DomainObjectACL -*', '*Write-HijackDll*', '* -Rhosts * -Password * -Directory * -Dictionary *', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*Update-ExeFunctions*', '*-Rhost * -Port * -Cmd *cmd /c*', '* -ConType bind *', '*Get-NetUser -UACFilter NOT_ACCOUNTDISABLE*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '* -p 1337:1337 -p 5000:5000*', '*Enable-SeDebugPrivilege*', 'usemodule */*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '* -mDNSTTL *', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Decrypt-CipherText*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*download *bloodhound*', '*Set-WorkingHours*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*Get-SQLInstanceDomain*', '*code_execution/*.ps1*', '* -PersistenceScriptName *', '*user Inveigh*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ProcessThoroughLocal*', '* \\Temp\\blah.exe*', '*Get-InternetExplorerBookmarks*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '* -DllName * -FunctionName *', '*Get-ChromeDump*', '*SpooferRepeat*', '* -ImpersonateUser *', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Launch Empire Server*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*injected into LSASS*', '*Start-MonitorTCPConnections.ps1*', '* -payload *-Lhost *-Lport*', '*1337*/api/agents/*/results?token=*', '* -ServiceName * -PipeName *', '*Set Listener dbx*', '*SpooferHostsReply*', '*usestager *launcher_lnk*', '*install  powershell-empire*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-BootKey*', '*uselistener onedrive*', '*Get-WMIRegLastLoggedOn*', '*usemodule privesc/*', '*Get-SiteListPassword*', '*Inveigh Relay*', '*useplugin csharpserver*', '*Get-LastLoggedon -*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '* -Enumerate * -Module *', '*Invoke-Kerberoast*', '*Get-BrowserInformation*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*empire --server *', '*Test-ServiceDaclPermission*', '*Decrypt-Bytes*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*Get-ChromeHistory*', '*Empire Framework GUI*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*Invoke-ThreadedFunction*', '*/xar-1.5.2.tar.gz*', '* -Username * -Hash * -Command *', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '* -RevToSelf *', '*/tools/psexec.rb*', '* -NoBase64 *', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '* -Rhosts * -Path *.txt -Port *', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '* -SpooferIP *', '* -Hosts * -TopPorts *', '*/client/generated-stagers/*', '* -type user -search * -DomainController * -Credential * -list yes*', '* Inveigh-*', '*Get-NetForestDomain*', '*\\hijackers\\*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', 'psenum *', '*StopInveigh*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*-DumpForest *', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '* empire.arguments*', '*Get-PEBasicInfo*', '* -CollectionMethod stealth*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*usestager *shellcode*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*invoke obfuscation*', '*function psenum*', '*Invoke-PowerDump*', '*generate_stageless*', '*usemodule powershell/persistence*', '*obfuscated_module_source/*', '*echo * > \\\\.\\pipe\\*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*Get-ChromeBookmarks*', '* -Target * -InitialGrooms *', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*usestager *ducky*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'dest_url': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'uri': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'uri_query': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'query': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url_domain': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'uri_path': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'domain': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'QueryName': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'QueryResults': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'DestinationHostname': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'DestinationIp': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'http_referrer': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'http_referrer_domain': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'http_user_agent': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'dest_nt_host': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'sender': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'recipient': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'orig_recipient': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'subject': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url.domain': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url.full': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url.original': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'url.query': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'user_agent.original': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'network.application': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'http.request.body.content': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'http.request.referrer': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'email.from.address': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'dns.question.name': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}, {'destination.domain': ['*Invoke-BackdoorLNK*', '*Exploit-Jenkins.ps1*', '*/situational_awareness/*.exe', '*Get-KeePassINIFields*', '*port_forward_pivot.py*', '*Invoke-WinEnum*', '*Get-SQLServerLoginDefaultPw*', '*SpooferLearningInterval*', '*/api/agents/*/kill?token=*', '*Get-DecryptedCpassword*', '*/api/agents/CXPLDTZCKFNT3SLT/shell?*', '*ReflectivePick_x86_orig.dll*', '*Out-Minidump.ps1*', '*/download-stager.js*', '*/api/reporting/type/checkin?token=*', '*Invoke-ShellcodeMSIL*', '*make_smb1_free_hole_session_packet*', '*-PWDumpFormat*', '*powershell_collection_screenshot*', '*Set-ServiceBinPath*', '*DecryptWinSCPPassword*', '*generate_powershell_shellcode*', '*powershell_privesc_bypassuac_eventvwr*', '*ConvertFrom-LDAPLogonHours*', '*StarkillerSnackbar.vue*', '*Get-VaultCredential.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-WscriptElevate*', '*Get-NetFileServer*', '*Invoke-WScriptBypassUAC*', '*SMBNTLMChallenge*', '*Invoke-ReflectivePEInjection*', '*-DllInjection.ps1*', '*-EventVwrBypass*', '*make_kernel_shellcode*', '*Bitmap-Elevate*', '*Get-RickAstley.ps1*', '*Find-InterestingDomainShareFile*', '*Get-KeePassXMLFields*', '*Invoke-EgressCheck*', '*ProcessPPKFile*', '*Install-SSP.ps1*', '*BypassUACTokenManipulation*', '*Invoke-Vnc*', '*Invoke-EnvBypass*', '*Invoke-PsExec*', '*Invoke-SMBAutoBrute*', '*/network/bloodhound3*', '*generate_python_shellcode*', '*Invoke-EventVwrBypass*', '*Invoke-BackdoorLNK*', '*Invoke-Ntsd.ps1*', '*Invoke-ReflectivePEInjection*', '*Invoke-Tater.ps1*', '*Get-DomainSpn*', '*Invoke-UserHunter*', '*Get-USBKeystrokes*', '*Invoke-ExecuteMSBuild*', '*PowerUp.ps1*', '*/api/agents/all/shell?token=*', '*Persistence.psm1*', '*powerview.ps1*', '*Invoke-CredentialInjection*', '*1337*/api/creds?token=*', '*Invoke-EgressCheck.ps1*', '*/empire:latest*', '*Invoke-SQLOSCmd.ps1*', '*SMBRelayChallenge*', '*MalleableProfiles.vue*', '*Get-PacketNetBIOSSessionService*', '*ProcessPuTTYLocal*', '*Invoke-PortBind*', '*Invoke-Portscan*', '*DownloadAndExtractFromRemoteRegistry*', '*Invoke-Inveigh*', '*SMBNTLMChallenge*', '*Find-Fruit.*', '*BloodHound.ps1*', '*Find-RDPClientConnections*', '*Invoke-MS16135.ps1*', '*Invoke-SQLOSCmd.ps1*', '*Invoke-WinEnum.ps1*', '*New-HoneyHash.ps1*', '*tree_connect_andx_request*', '*New-ElevatedPersistenceOption*', '*/data/empire.db*', '*Get-SiteListPassword*', '*Invoke-TokenManipulation.ps1*', '*Get-SystemNamedPipe*', '*Invoke-Empire*', '*Export-PowerViewCSV*', '*WScriptBypassUAC*', '*Get-DomainDFSShareV2*', '*/api/agents/stale?token=*', '*/EmpireProject*', '*generate_python_exe*', '*Invoke-PatchDll*', '*Invoke-SessionGopher*', '*empireadmin*', '*Get-DomainSPNTicket*', '*Get-SecurityPackages.ps1*', '*stagers/*/aes.py*', '*Get-SystemDNSServer.ps1*', '*Find-4648Logons*', '*ReflectivePick_x64_orig.dll*', '*/Invoke-RunAs.ps1*', '*Get-RegistryAutoLogon*', '*/evilhost:*', '*Invoke-SMBExec.ps1*', '*Invoke-FodHelperBypass*', '*HTTP-Login.ps1*', '*PowerUp.ps1*', '*Find-PSScriptsInPSAppLog*', '*empire/client/*.py*', '*Invoke-MS16032*', '*/stagers/*.ps1*', '*Invoke-PatchDll*', '*Get-Keystrokes*', '*Set-MacAttribute.ps1*', '*NTLMChallengeBase64*', '*generate_powershell_exe*', '*/api/agents/XMY2H2ZPFWNPGEAP?token=*', '*Empire-master*', '*/api/v2/starkiller*', '*Get-DecryptedSitelistPassword*', '*Invoke-PowerDump*', '*bc-security/empire*', '*Invoke-EnumerateLocalAdmin*', '*Find-TrustedDocuments*', '*Invoke-BypassUAC*', '*/ReferenceSourceLibraries/Sharpire*', '*Find-Fruit.ps1*', '*New-InMemoryModule*', '*stagers/*/rc4.py*', '*Invoke-EnvBypass.ps1*', '*/api/reporting/agent/initial?token=*', '*SpooferLearningDelay*', '*make_smb2_payload_headers_packet*', '*ProcessWinSCPLocal*', '*/Empire.git', '*EmpireCORSMiddleware*', '*MetasploitPayload.ps1*', '*stagers/*/get_sysinfo.py*', '*Invoke-Paranoia*', '*Get-GPPPassword.ps1*', '*Invoke-ExecuteMSBuild.ps1*', '*DecryptNextCharacterWinSCP*', '*/api/modules/collection/*?token=*', '*Do-AltShiftEsc*', '*Get-WMIRegMountedDrive*', '*Create-SuspendedWinLogon*', '*Invoke-CredentialInjection*', '*powershell_collection_keylogger*', '*Inject-LocalShellcode*', '*SharpTemplateResources/cmd/*', '*Find-4624Logons*', '*PowerShellEmpire*', '*ProcessRDPFile*', '*/ps-empire*', '*Invoke-BypassUAC*', '*Get-VaultCredential*', '*Invoke-SSHCommand.ps1*', '*obfuscate_command*', '*Invoke-PostExfil*', '*Invoke-PSInject*', '*Invoke-ReflectivePEInjection*', '*Invoke-VoiceTroll.ps1*', '*Get-BrowserData.ps1*', '*/api/reporting/msg/*?token=*', '*Get-WMIRegCachedRDPConnection*', '*Invoke-ShellCommand*', '*ProcessRDPLocal*', '*SMBNTLMResponse*', '*Get-ModifiableRegistryAutoRun*', '*NBNSBruteForceSpoofer*', '*code_execution/*.dll*', '*ExfilDataToGitHub*', '*Find-WMILocalAdminAccess*', '*New-UserPersistenceOption*', '*Get-PacketRPCRequest*', '*Invoke-NinjaCopy*', '*python_modules/keyboard.zip*', '*Do-AltShiftTab*', '*Exploit-JBoss.ps1*', '*NBNSSpoofer*', '*smb1_anonymous_login*', '*/x64_slim.dll*', '*Import-DllInRemoteProcess*', '*Get-PacketSMB*', '*code_execution/*.exe*', '*/empire/client/*', '*empire/server/downloads/*', '*Invoke-Kerberoast*', '*KeeThief.ps1*', '*Invoke-PSInject.ps1*', '*Invoke-SmbScanner*', '*NBNSBruteForceHost*', '*Set-DesktopACLToAllow*', '*New-HoneyHash*', '*ProcessSuperPuTTYFile*', '*Get-SitelistFields*', '*//localhost:1337*', '*powershell_code_execution_invoke_assembly*', '*Get-System.ps1*', '*KeeThief.*', '*make_smb1_anonymous_login_packet*', '*/api/stagers/dll?token=*', '*Get-RegistryAlwaysInstallElevated*', '*Enable-SeAssignPrimaryTokenPrivilege*', '*EmpireProject*', '*Get-FoxDump*', '*Invoke-InveighRelay.ps1*', '*Create-WinLogonProcess*', '*empire/server/*.py*', '*Exploit-Jenkins*', '*Import-DllInRemoteProcess*', '*Create-NamedPipe*', '*Invoke-Tater.*', '*Inject-RemoteShellcode*', '*Invoke-PacketKnock*', '*Invoke-ImpersonateUser*', '*Exploit-JBoss.ps1*', '*/ducky.py', '*http_malleable.py*', '*mDNSSpoofer*', '*Invoke-NetRipper*', '*/MailRaider.ps1*', '*empire-test-kalirolling*', '*Get-GPPInnerFields*', '*Get-DomainDFSShareV1*', '*dumpCredStore.ps1*', '*ConvertTo-Rc4ByteStream*', '*/api/stagers?token=*', '*Find-LocalAdminAccess*', '*Get-SPN.ps1*', '*1337*/api/listeners?token=*', '*powershell_credentials_tokens*', '*Invoke-UserImpersonation*', '*SnifferSpoofer*', '*/HTTP-Login.ps1*', '*Get-ModifiableScheduledTaskFile*', '*Persistence.psm1*', '*Invoke-SmbScanner*', '*New-InMemoryModule*', '*Get-ClipboardContents.ps1*', '*Invoke-SMBScanner*', '*/trollsploit/*', '*smb1_anonymous_connect_ipc*', '*Get-DomainSPNTicket*', '*SMBRelayResponse*', '*Empire-Sponsors.git*', '*Inject-BypassStuff*', '*Invoke-Paranoia*', '*empire_server.*', '*http*/localhost*:1337*', '*Find-AppLockerLogs*', '*-KeePassConfigTrigger*', '*Invoke-CallbackIEX*', '*powershell_management_psinject*', '*Invoke-DCOM.ps1*', '*Invoke-NinjaCopy*', '*empire-priv.key*', '*egresscheck-framework*', '*Get-SiteListPassword*', '*/api/users/1/disable?token=*', '*Invoke-DCSync*', '*empire-chain.pem*', '*Get-ClipboardContents*', '*PowerBreach.ps1*', '*Write-HijackDll*', '*SpooferIPsReply*', '*ps-empire*', '*KeePassConfig.ps1*', '*Invoke-ARPScan*', '*ListMetasploitPayloads*', '*/api/modules/credentials*?token=*', '*Invoke-PostExfil*', '*powershell_privesc_sherlock*', '*server/modules/csharp/*', '*Invoke-PatchDll*', '*keyword_obfuscation*', '*Get-DomainSearcher*', '*ProcessFileZillaFile*', '*SpooferHostsIgnore*', '*BC-SECURITY/Starkiller*', '*Import-DllImports*', '*Find-PathDLLHijack*', '*Get-UserBadPwdCount*', '*Invoke-Vnc.ps1*', '*smb_eternalblue*', '*Stage-gSharedInfoBitmap*', '*make_smb1_nt_trans_packet*', '*Add-PSFirewallRules*', '*code_execution/*.ps1*', '*Get-DCBadPwdCount*', '*LLMNRSpoofer*', '*powershell_management_spawn*', '*ACBypassTest*', '*Find-ProcessDLLHijack*', '*Get-ChromeDump*', '*SpooferRepeat*', '*Invoke-DllInjection*', '*Get-KeePassDatabaseKey*', '*Invoke-ClipboardMonitor*', '*Write-HijackDll*', '*ExfilDataToGitHub*', '*-PsExecCmd*', '*Get-SQLServerLoginDefaultPw*', '*SpooferIPsIgnore*', '*Get-GPPPassword*', '*Install-ServiceBinary*', '*Start-MonitorTCPConnections.ps1*', '*1337*/api/agents/*/results?token=*', '*SpooferHostsReply*', '*Get-BloodHoundData*', '*Get-PacketRPCBind*', '*Invoke-Shellcode.ps1*', '*empire/server/downloads/logs/*', '*Get-WMIRegLastLoggedOn*', '*Get-SiteListPassword*', '*/api/admin/shutdown?token=*', '*make_smb1_trans2_explo*', '*Invoke-Kerberoast*', '*Receive-AgentJob*', '*/smb/psexec.rb*', '*Invoke-FodHelperBypass*', '*Test-ServiceDaclPermission*', '*Get-PacketNTLMSSPAuth*', '*Invoke-SessionGopher*', '*Invoke-MS16032*', '*/stagers/CSharpPS*', '*Invoke-SDCLTBypass*', '*/xar-1.5.2.tar.gz*', '*make_smb1_echo_packet*', '*Invoke-PsExec.ps1*', '*Get-DomainManagedSecurityGroup*', '*/tools/psexec.rb*', '*Invoke-ServiceAbuse*', '*/server/common/stagers.py*', '*stagers/*/diffiehellman.py*', '*NBNSBruteForcePause*', '*Invoke-ARPScan.ps1*', '*/client/generated-stagers/*', '*Enum-Creds*', '*Invoke-SMBAutoBrute*', '*/lateral_movement/*.ps1', '*Invoke-MS16135*', '*/api/listeners/all?token=*', '*http*/127.0.0.1*:1337*', '*Empire-GUI.git*', '*Get-ActiveTCPConnections*', '*csharp_inject_bof_inject*', '*Get-RickAstley*', '*EternalBlue.ps1*', '*Get-SQLSysadminCheck*', '*/persistence/*.ps1', '*Find-TrustedDocuments.ps1*', '*sync-starkiller*', '*Get-PacketNTLMSSPNegotiate*', '*Invoke-PowerDump*', '*generate_stageless*', '*obfuscated_module_source/*', '*Find-InterestingDomainAcl*', '*/api/agents/all/kill?token=*', '*make_smb2_payload_body_packet*', '*Exploit-JMXConsole*', '*Find-KeePassconfig*', '*/persistence/*.psm1', '*NBNSBruteForceTarget*', '*Get-CachedGPPPassword*', '*make_kernel_user_payload*', '*Invoke-Portscan.ps1*']}], 'condition': 'selection'}
# <h1>Sigma Relatives</h4> This field defines the relationships between this Sigma rule and other detection rules, allowing for an integrated approach to threat detection and enhancing the overall effectiveness of the security infrastructure.
# <h1>Sigma Tags and Associations</h1> ['attack.T1003.001', 'attack.T1016', 'attack.T1020', 'attack.T1021.003', 'attack.T1021.004', 'attack.T1027', 'attack.T1033', 'attack.T1040', 'attack.T1041', 'attack.T1046', 'attack.T1047', 'attack.T1048', 'attack.T1049', 'attack.T1050', 'attack.T1051', 'attack.T1052', 'attack.T1053', 'attack.T1053.005', 'attack.T1054', 'attack.T1055', 'attack.T1056', 'attack.T1056.001', 'attack.T1056.004', 'attack.T1057', 'attack.T1058', 'attack.T1059', 'attack.T1059.001', 'attack.T1059.003', 'attack.T1060', 'attack.T1061', 'attack.T1062', 'attack.T1063', 'attack.T1064', 'attack.T1065', 'attack.T1066', 'attack.T1067', 'attack.T1068', 'attack.T1069', 'attack.T1070', 'attack.T1070.006', 'attack.T1071', 'attack.T1071.001', 'attack.T1072', 'attack.T1073', 'attack.T1074', 'attack.T1075', 'attack.T1076', 'attack.T1077', 'attack.T1078', 'attack.T1079', 'attack.T1080', 'attack.T1081', 'attack.T1082', 'attack.T1083', 'attack.T1084', 'attack.T1085', 'attack.T1086', 'attack.T1087', 'attack.T1087.001', 'attack.T1087.002', 'attack.T1088', 'attack.T1089', 'attack.T1090', 'attack.T1091', 'attack.T1092', 'attack.T1093', 'attack.T1094', 'attack.T1095', 'attack.T1096', 'attack.T1097', 'attack.T1098', 'attack.T1099', 'attack.T1100', 'attack.T1101', 'attack.T1102', 'attack.T1102.002', 'attack.T1103', 'attack.T1104', 'attack.T1105', 'attack.T1106', 'attack.T1107', 'attack.T1108', 'attack.T1109', 'attack.T1110', 'attack.T1111', 'attack.T1112', 'attack.T1113', 'attack.T1114', 'attack.T1114.001', 'attack.T1115', 'attack.T1116', 'attack.T1117', 'attack.T1118', 'attack.T1119', 'attack.T1120', 'attack.T1121', 'attack.T1122', 'attack.T1123', 'attack.T1124', 'attack.T1125', 'attack.T1126', 'attack.T1127', 'attack.T1127.001', 'attack.T1128', 'attack.T1129', 'attack.T1130', 'attack.T1131', 'attack.T1133', 'attack.T1134', 'attack.T1134.002', 'attack.T1134.005', 'attack.T1135', 'attack.T1136', 'attack.T1136.001', 'attack.T1136.002', 'attack.T1137', 'attack.T1138', 'attack.T1139', 'attack.T1140', 'attack.T1141', 'attack.T1142', 'attack.T1143', 'attack.T1144', 'attack.T1145', 'attack.T1146', 'attack.T1147', 'attack.T1148', 'attack.T1149', 'attack.T1150', 'attack.T1152', 'attack.T1153', 'attack.T1154', 'attack.T1155', 'attack.T1156', 'attack.T1157', 'attack.T1210', 'attack.T1217', 'attack.T1482', 'attack.T1484.001', 'attack.T1518.001', 'attack.T1543.003', 'attack.T1546.008', 'attack.T1547.001', 'attack.T1547.005', 'attack.T1547.009', 'attack.T1548.002', 'attack.T1550.002', 'attack.T1552.001', 'attack.T1552.004', 'attack.T1555.003', 'attack.T1557.001', 'attack.T1558.001', 'attack.T1558.002', 'attack.T1558.003', 'attack.T1560', 'attack.T1562.001', 'attack.T1567.001', 'attack.T1567.002', 'attack.T1569.002', 'attack.T1573.002', 'attack.T1574.001', 'attack.T1574.004', 'attack.T1574.007', 'attack.T1574.008', 'attack.T1574.009', 'attack.T1615', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0009', 'attack.TA0010', 'attack.TA0011', 'attack.TA0011 ', 'attack.TA0040']
# <h4>Sigma Authors</h4> @mthcht
# <h4>Sigma Unique ID</h4> 8deb608e-11ad-4a87-8e9f-5a8fedef1789
# </ol>
# </details>

# %% [markdown]
# ###  Yara Rule(s)

# %% [markdown]
# <details><summary>8deb608e-11ad-4a87-8e9f-5a8fedef1789</summary>
# <ol>
# <h4>Raw</h4> Defined protocols for identifying patterns of malware and suspicious activity within the network infrastructure.
# <h4>Yara Location(s)</h4>
# Stored securely within the organization's cybersecurity infrastructure, accessible to authorized security analysts.
# <h4>Yara Confidence</h4>
# Set at a provisional level, subject to validation and refinement based on emerging threat intelligence and detection efficacy.
# <h4>Yara Assurance</h4> Highly reliable, backed by rigorous testing and validation processes to ensure accuracy and effectiveness.
# <h4>Yara Queries</h4>
# Crafted to precisely navigate and analyze vast data sets for potential security threats, utilizing optimized search patterns.
# <h4>Yara Authors</h4> Developed by a team of skilled cybersecurity professionals, specialists in malware analysis and threat detection.
# <h4>Yara Rule's Unique ID</h4> Unique identifier assigned to each rule for tracking and management purposes within the security system.
# </ol>
# </details>

# %% [markdown]
# # Metadata

# %% [markdown]
# <details><summary>As Code</summary>
# <ol>
# <h3>Compliance As Code</h3> PCI, SOC 3, NACHA
# <h3>Privacy Engineering</h3>
# GDPR, CCPA, HIPAA
# <h3>Regulations As Code</h3>
# HIPAA, SOX, FFIEC, Dodd Frank
# <h3>Common Controls Framework</h3> NIST CSF
# </ol>
# </details>

# %% [markdown]
# # AGI ML Models</ol>
# </details>

# %% [markdown]
# ## AGI Prompting
#  Recognize: Initiate connection to the Wintermute system through a specialized interface. Enter the system using a secure, binary-encoded password. Begin monitoring the network for any signs of rogue AI entities and evaluate the security measures currently in place. Identify: Navigate the complex data streams within the Wintermute system, employing advanced algorithms to manage and analyze data flows. Your primary task is to identify anomalies and decrypt Wintermute's confidential digital records to reveal the cause of its unusual interactions with other network-connected devices. Stabilize: Upon detecting any irregularities or security breaches, take immediate action to contain these issues. Implement security protocols to limit the exposure of sensitive data and prevent further unauthorized access by isolating the affected segments of the network. Eradicate: Resolve the security issues by removing any rogue elements and restoring secure configurations. Update the system’s security measures to fortify defenses against future intrusions. Complete the mission by ensuring that all systems are free from vulnerabilities and that data integrity is maintained. Conclusion: Report findings and recommendations for future security improvements. Your expertise has been crucial in resolving this complex cybersecurity challenge and ensuring the integrity of the Wintermute system.

# %% [markdown]
# ## AGI Configuration(s)
#  Recognize: Engage with the system as a skilled cybersecurity expert, tasked with analyzing encrypted data. Initiate your connection to the system and prepare to navigate through complex data structures and encryption layers. Identify: Use advanced analytical techniques to decrypt and interpret data, searching for hidden patterns and anomalies in Wintermute’s encrypted communications. Employ your expertise in cybersecurity to detect any obscured or concealed information. Stabilize: Implement necessary measures to secure the data integrity, ensuring that no further obfuscation or encryption compromises system clarity and functionality. Ensure the stability of system interactions as you process and clarify data. Eradicate: Resolve any encryption challenges and finalize the decryption process, removing barriers to clear data interpretation. Update system protocols to enhance future data accessibility and security, ensuring robust protection against similar challenges. Conclusion: Document your processes and findings, providing a clear path forward for maintaining system security and data transparency. Your specialized skills have been crucial in navigating this complex decryption task, ensuring system integrity and reliable data access.

# %% [markdown]
# </ol>
# </details>

# %% [markdown]
# #### Document Authors
# John Menerick

# %% [markdown]
# #### Creation Date
# 2022/01/01

# %% [markdown]
# #### Last Modified Date
# 2024/02/29

# %% [markdown]
# #### Last Modified Date
#  2024/02/29

# %% [markdown]
# #### Last Reviewed Date
# 1969/01/01

# %% [markdown]
# #### Document License
#  MIT
