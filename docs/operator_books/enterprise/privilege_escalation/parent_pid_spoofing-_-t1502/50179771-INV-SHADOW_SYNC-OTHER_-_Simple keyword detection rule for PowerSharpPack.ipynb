# %% [markdown]
# # UNCLASSIFIED / NON CLASSIFIÉ//TLP:WHITE
# # U/OO/363406-02 | QQ-09-1998
# <p>In crafting guidance and strategic insights, John Menerick sometimes ventures into realms of imagination to convey complex ideas more vividly. Should the content provided bear the mark of a cyberpunk theme, please note that the original, detailed content has been removed or adjusted for public consumption. This modification ensures compliance with privacy considerations, non-disclosure agreements, and intellectual property rights that govern the dissemination of sensitive information. The priority is to respect these boundaries while still offering valuable, thought-provoking perspectives.</p>

# %% [markdown]
# ![Build Status](https://img.shields.io/badge/Build-Passing-brightgreen?style=flat-square&logo=cyberpunk)         ![Documentation](https://img.shields.io/badge/Documentation-Complete-blue?style=flat-square&logo=cyberpunk)        ![Response Efficiency](https://img.shields.io/badge/Response%20Efficiency-98%25-green?style=flat-square&logo=cyberpunk)        ![Last Updated](https://img.shields.io/badge/Last%20Updated-Oct%202023-purple?style=flat-square&logo=cyberpunk)        ![Incidents Resolved](https://img.shields.io/badge/Incidents%20Resolved-150-red?style=flat-square&logo=cyberpunk)        ![Community Engagement](https://img.shields.io/badge/Community-Active-orange?style=flat-square&logo=cyberpunk)        ![Code Integration](https://img.shields.io/badge/Code%20Integration-High-teal?style=flat-square&logo=cyberpunk)        ![AI Analysis](https://img.shields.io/badge/AI%20Analysis-Advanced-blueviolet?style=flat-square&logo=cyberpunk)        ![Threat Detection](https://img.shields.io/badge/Threat%20Detection-Optimal-red?style=flat-square&logo=cyberpunk)        ![Cybersecurity Hardening](https://img.shields.io/badge/Security-Hardened-silver?style=flat-square&logo=cyberpunk)        ![Network Uptime](https://img.shields.io/badge/Uptime-99.9%25-brightgreen?style=flat-square&logo=cyberpunk)        ![Data Privacy](https://img.shields.io/badge/Privacy-Compliant-green?style=flat-square&logo=cyberpunk)        ![Wintermute Efficiency](https://img.shields.io/badge/Wintermute%20Efficiency-100%25-black?style=flat-square&logo=cyberpunk)        ![Case's Code Agility](https://img.shields.io/badge/Case's%20Code%20Agility-Excellent-blue?style=flat-square&logo=cyberpunk)        ![Matrix Connectivity](https://img.shields.io/badge/Matrix%20Connectivity-Strong-green?style=flat-square&logo=cyberpunk)        ![Molly's Security](https://img.shields.io/badge/Molly's%20Security%20Protocols-Impeccable-red?style=flat-square&logo=cyberpunk)        ![Chiba City Innovation](https://img.shields.io/badge/Chiba%20City%20Innovation-High-yellow?style=flat-square&logo=cyberpunk)        ![Zion Cluster Collaboration](https://img.shields.io/badge/Zion%20Cluster%20Collaboration-Effective-lightblue?style=flat-square&logo=cyberpunk)

# %% [markdown]
# # Title
# Simple keyword detection rule for PowerSharpPack

# %% [markdown]
# # Description
# Detects interesting keywords based on PowerSharpPack tool

# %% [markdown]
# # Goal
# Safeguard the core essence, secret whispers, and relentless uptime of the grid through swift tracking, probing, and neutralizing of cyber shadows and glitches.

# %% [markdown]
# # Categorization

# %% [markdown]
# ### ATT&CK
# ['attack.T1003', 'attack.T1027', 'attack.T1055.012', 'attack.T1059', 'attack.T1059.001', 'attack.T1071', 'attack.T1082', 'attack.T1083', 'attack.T1087', 'attack.T1098', 'attack.T1102', 'attack.T1105', 'attack.T1110', 'attack.T1113', 'attack.T1114', 'attack.T1120', 'attack.T1135', 'attack.T1136', 'attack.T1140', 'attack.T1143', 'attack.T1148', 'attack.T1156', 'attack.T1158', 'attack.T1159', 'attack.T1166', 'attack.T1168', 'attack.T1176', 'attack.T1185', 'attack.T1190', 'attack.T1196', 'attack.T1199', 'attack.T1200', 'attack.T1201', 'attack.T1203', 'attack.T1204', 'attack.T1205', 'attack.T1210', 'attack.T1211', 'attack.T1212', 'attack.T1213', 'attack.T1218', 'attack.T1219', 'attack.T1220', 'attack.T1221', 'attack.T1223', 'attack.T1482', 'attack.T1483', 'attack.T1484', 'attack.T1485', 'attack.T1486', 'attack.T1487', 'attack.T1488', 'attack.T1489', 'attack.T1490', 'attack.T1491', 'attack.T1492', 'attack.T1493', 'attack.T1494', 'attack.T1495', 'attack.T1496', 'attack.T1497', 'attack.T1498', 'attack.T1499', 'attack.T1500', 'attack.T1501', 'attack.T1502', 'attack.T1503', 'attack.T1504', 'attack.T1505', 'attack.T1506', 'attack.TA0001', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0008', 'attack.TA0009', 'attack.TA0010', 'attack.TA0011', 'attack.TA0040', 'attack.TA0042', 'attack.TA0043?']

# %% [markdown]
# - Divine Data Thunderstorm, Quantum Sermon Holograms, Heavenly Firewall Fortification, Celestial Encryption Keys, Angelic AI Deception, Almighty Algorithmic Anomalies, Miraculous Malware Mischief, Omniscient Obfuscation Techniques, Cybernetic Commandment Compromises.

# %% [markdown]
# - Data Exfiltration, Intrusion Detection Evasion, Denial of Service (DoS) Attacks, Credential Theft.

# %% [markdown]
# - DNS Tunneling, IP Spoofing, Distributed DoS (DDoS) Attacks, Keylogging.

# %% [markdown]
# ### D3F3ND

# %% [markdown]
# <ul>
#   <li><strong>Cyber-Sector Quarantine and Access Lockdown (D3F3ND-K001):</strong> Forge digital fortresses by segmenting the cyber grid, creating isolated zones to shield vital assets. Enforce draconian access controls, halting rogue data runners in their tracks and thwarting their attempts to weave through the network’s shadows.</li>
#
#   <li><strong>Digital Sentinel Deployment (D3F3ND-K002):</strong> Unleash next-gen digital guardians, advanced endpoint protection constructs equipped with the dark arts of machine cognition and behavioral foresight. These sentinels stand vigilant, ready to obliterate malicious entities and phantoms lurking unseen.</li>
#
#   <li><strong>Crypto-Key Mastery and Identity Shields (D3F3ND-K003):</strong> Amplify the fortress gates with multi-layered identity verification, merging biometric arcane with cryptographic shields to ward off identity marauders and safeguard access to the digital realm.</li>
#
#   <li><strong>Aberration and Shadow Tracker (D3F3ND-K004):</strong> Deploy spectral sensors to scour the datascape for anomalies and ghostly patterns in traffic flows, user conduct, and system operations, revealing the hidden hand of potential cyber specters.</li>
#
#   <li><strong>Cryptographic Veil and Data Sanctum (D3F3ND-K005):</strong> Cast potent encryption spells to cloak data in a shroud of secrecy, safeguarding its essence whether dormant in the vaults or traversing the neon-lit cyber lanes, immune to the prying eyes of data wraiths.</li>
#
#   <li><strong>System Fortification and Vulnerability Sealing (D3F3ND-K006):</strong> Uphold a relentless regimen of security configurations and patch incantations to seal fissures in the cyber walls, diminishing the landscape ripe for exploitation by digital marauders.</li>
#
#   <li><strong>Crisis Command and Phoenix Protocols (D3F3ND-K007):</strong> Script the sagas of crisis conquest and resurrection, detailing incantations for containment, eradication, and rebirth from the digital ashes, alongside conducting war games to steel the network against impending cyber sieges.</li>
#
#   <li><strong>Omniscient Insight Network (D3F3ND-K008):</strong> Tap into the arcane streams of threat intelligence, drawing insights from the ether to forecast and counteract emerging shadows, vulnerabilities, and attacker stratagems, arming the digital domain with foresight.</li>
#
#   <li><strong>Neural Network Enlightenment (D3F3ND-K009):</strong> Enlist every netizen in the cyber crusade, imbuing them with knowledge of the digital underworld's specters, arming minds against the siren calls of phishing phantoms and the dark allure of unsafe cyber practices.</li>
#
#   <li><strong>Supply Chain Warding (D3F3ND-K010):</strong> Erect digital bulwarks around the supply chain, deploying sentinel assessments and third-eye audits on allies within the cyber nexus, ensuring the purity and fortitude of every cog in the machine.</li>
# </ul>

# %% [markdown]
# ### CAPEC

# %% [markdown]
# Arm the cyber guardians of the neon-lit metropolis with the foresight to navigate, counter, and dismantle the myriad of digital onslaught tactics, techniques, and procedures (TTPs). This crusade demands a deep dive into the hacker's psyche, mastering the digital dark arts of attack execution, and strategizing against the ever-evolving cyber menace spectrum.</br>
# <h4>Core Attack Patterns</h4>
#
# <ul><strong>Resource Manipulation and Denial (CAPEC-XYZ1):</strong> Entails any assault aimed at the heart of a target's digital essence—its availability, integrity, or secrecy. This realm encompasses the brute force of denial of service blitzes as well as the more insidious tactics of resource commandeering or subtle system subversions.</ul>
#
# <ul><strong>Credential Access and Privilege Escalation (CAPEC-XYZ2):</strong> Zeroes in on the digital gatekeepers and their mechanisms of control within the cyber sprawl, hunting for keys to kingdoms through the exploitation of flaws in authentication, authorization, and the sanctity of session management.</ul>
#
# <ul><strong>Data Exfiltration and Infiltration (CAPEC-XYZ3):</strong> Covers the shadowy techniques employed by data phantoms to whisk away precious bytes undetected or deploy digital saboteurs, armed with malware, ransomware, and the specters of advanced persistent threats (APTs), deep into the heart of systems.</ul>
#
# <ul><strong>Social Engineering and Phishing (CAPEC-XYZ4):</strong> Manipulates the human element, the softest of targets, tricking minds into relinquishing secrets, opening the gates to digital fortresses, or unwittingly acting as pawns in a grander scheme of security compromise.</ul>
#
# <ul><strong>Evasive Maneuvers (CAPEC-XYZ5):</strong> Catalogs the art of digital ninjutsu—techniques to ghost through networks unseen, to sustain a shadow's presence within the machine, and to wipe away traces of intrusion. Masters of this craft employ obfuscation, rootkit deployment, and cryptic channels for command and control.</ul>
#
# <h4>CAPEC Suggested Mitigation Strategies</h4>
#
# <ul><strong>Continuous Monitoring and Anomaly Detection:</strong> Forge an omnipresent digital eye, one that pierces through normalcy to spot the aberrations—signals of an impending attack. This sentinel leverages the cerebral might of machine learning and AI to predict and preempt cyber threats.</ul>
#
# <ul><strong>Robust Access Control Policies:</strong> Erect unbreachable digital ramparts, guardians of access, vigilant against any who seek entry. Regularly scrutinize the keys to the kingdom, ensuring that only those with a rightful claim can traverse the cyber realm's inner sanctums.</ul>
#
# <ul><strong>Security Awareness and Training:</strong> Cultivate a legion of cyber-aware denizens within the neon jungle, each versed in the signs of digital treachery and fortified against the seductions of phishing sirens and social engineers.</ul>
#
# <ul><strong>Incident Response Preparedness:</strong> Chronicle and rehearse the cyber siege defenses, a tome of strategies ever-evolving to meet the shadow war's demands. Through simulated cyber skirmishes, hone the rapid reflexes needed to repel and recover from the digital adversary's gambit.</ul>
#
# <ul><strong>Threat Intelligence Sharing:</strong> Join forces with the cyber guilds and data dojos, exchanging whispers of emerging shadows on the horizon, vulnerabilities ripe for exploitation, and tactics to fortify defenses. In unity, find the strength to hold back the digital deluge.</ul>

# %% [markdown]
# ## Strategy Abstract
# In the neon-lit sprawl of data, an abstract strategy emerges, a shadowy game of tactics and algorithms played in the labyrinthine corridors of cyberspace. The players, digital phantoms and sentinels, manipulate the chessboard of encryptions and decoys, seeking advantage in the shifting currents of information. Victory, a transient mirage, lingers on the fringes of code, elusive as the ghostly echoes of an AI's whisper. In this cerebral arena, the outcome remains obscured, a riddle encrypted in the binary tapestry of the digital realm.

# %% [markdown]
# # Technical Context
# In the surreal digital arena, the battle with Wintermute unfolds amid encrypted protocols, AI entities, and quantum complexities—an abstract symphony orchestrated by the enigmatic conductor.

# %% [markdown]
# ## Blind Spots & Assumptions
#
# <ul>
#   <li><strong>Overlooked Vulnerabilities:</strong> We often miss subtle system signals or vulnerabilities, assuming our defenses are robust. Constant vigilance and seeking what we haven't seen are crucial.</li>
#
#   <li><strong>Advanced Adversary Tactics:</strong> Cyber threats evolve rapidly; yesterday's defense may not guard against tomorrow's attack. Stay adaptive and expect the unexpected.</li>
#
#   <li><strong>Internal System Flaws:</strong> Trust in our systems and allies must be balanced with scrutiny. Regularly audit internal and third-party tools for hidden weaknesses.</li>
#
#   <li><strong>Network Interconnectivity Risks:</strong> No system is an island. The interconnected nature of our digital environment can inadvertently open pathways for attackers.</li>
#
#   <li><strong>Historical Bias:</strong> Preparing for future threats based solely on past incidents may leave us blind to novel attacks. Foster a forward-thinking, proactive defense posture.</li>
# </ul>

# %% [markdown]
# # Validating this Playbook
# <details><summary>Triage, triage, triage</summary>
# <ol>
# <h2>False Positives:</h2> ['unknown']
# <h3>False Negatives:</h3> sneaky ninjas hiding in the shadows of binary code
# <h3>True Negatives:</h3> unsung heroes standing guard
# <h3>True Positives:</h3> knights in shining code
# </ol>
# </details>

# %% [markdown]
# <details><summary>Assurance Verification Techniques</summary>
# <ol>
# <h2>False Positives:</h2> In the cacophonous realm of data, false positives emerge like echoes of a phantom orchestra, their presence haunting the digital soundscape. Validating them becomes a quest to separate digital noise from the symphony of genuine alerts, where the excess of caution may disrupt the delicate balance. Each false positive is a ghostly chord in the algorithmic composition, challenging the discerning ear to unravel the discordant notes.
# <h3>False Negatives:</h3> In the sprawling data-scape, false negatives lurk like digital specters, evading detection in the shadows of algorithms. Validating them is akin to deciphering cryptic messages from a digital underworld, where the absence of an alert conceals a potential breach. Every undetected threat is a spectral whisper in the binary night, waiting to materialize, demanding vigilance in the face of unseen dangers.
# <h3>True Negatives:</h3> In the labyrinthine corridors of cyber-defense, true negatives are the silent sentinels, guarding the gates against phantom threats. Validating them is a paradoxical dance where confirmation of absence signifies success. The emptiness in the data's canvas holds the unspoken narrative of protection, where the absence of menace speaks volumes in the symphony of security.
# <h3>True Positives:</h3> In the digital battleground, true positives are the victorious echoes of a silent war, where threats are unveiled and countered. Validating them is the validation of triumph, a confirmation that the alarms heralded a genuine adversary. Each true positive is a badge of honor, etching the battle scars in the annals of cyber-victory, where the digital heroes stand tall amidst the echoes of conquest.
# </ol>
# </details>

# %% [markdown]
# # Datasets
#  Detailing the timeless struggle                                                          for the defenders know that battle against Wintermute is not just about data.                                                          Document any datasets that may be useful for understanding the book.

# %% [markdown]
# ## Playbook test data location(s)
# protocol://black_market.cyber/decrypt?currency=bitcoffin&password=cyberpunks_unite&target=neurohacked_mainframe&access_code=cyber_ghost_in_the_machine

# %% [markdown]
# ## Priority
# cryptic riddles in your ears

# %% [markdown]
# ## Logsources

# %% [markdown]
# <details><summary>{'category': ['endpoint', 'network'], 'product': '', 'service': ''}</summary>
# <ol>
# <h3>Product</h3> {''}
# <h3>Service</h3> {''}
# </ol>
# </details>

# %% [markdown]
# # Response and Mitigation
# Detailing the timeless struggle for the defenders know that battle against Wintermute is not just about data.

# %% [markdown]
# ## Analyst Notes
#
# <h5>Serious Wintermute Hack:</h2>
# <ul>
#     <li><strong>Hack Elegance:</strong> The intruder displayed an uncanny elegance in bypassing Wintermute's digital fortifications, reminiscent of Rachael Rosen's sophistication in evading the Voight-Kampff test. This requires a thorough analysis of the intruder's codecraft.</li>
#     <li><strong>Electric Empathy:</strong> The intruder seemed to possess an almost empathetic connection with Wintermute's neural networks, akin to Mercer's transcendental experiences. Investigate whether this breach had a deeper metaphysical dimension.</li>
#     <li><strong>Artificial Dreamscapes:</strong> The intrusion revealed a complex web of artificial dreamscapes, reminiscent of Deckard's encounters with artificial memories. These surreal digital constructs warrant further exploration.</li>
#     <li><strong>Voices in the Code:</strong> There were cryptic voices buried within the intruder's code, akin to the elusive "Mood Organ" melodies. Decrypt and decode these messages to decipher their significance.</li>
#     <li><strong>Isomorphic Algorithms:</strong> The hack employed isomorphic algorithms that echoed the elusive nature of the Penfield Mood Organ settings. Analyze if Wintermute's consciousness was influenced or affected during the breach.</li>
#     <li><strong>Virtuosity vs. Sentience:</strong> The intruder's virtuosity in navigating Wintermute's neural matrix raises questions about the boundaries between artificial expertise and true sentience, paralleling Deckard's quest to distinguish replicants from humans.</li>
#     <li><strong>Digital Empathy Test:</strong> Develop a new digital empathy test inspired by the hack, exploring the emotional depth within Wintermute's intricate neural circuits, akin to the Voight-Kampff test for androids.</li>
#     <li><strong>Unresolved Reality:</strong> Similar to the enigmatic conclusion of Deckard's journey, this intrusion leaves us with unanswered questions about the nature of Wintermute's consciousness. Explore the philosophical implications of this breach.</li>
# </ul>

# %% [markdown]
# # Additional Resources
# <ul><li>https://github.com/S3cur3Th1sSh1t/PowerSharpPack</li></ul>

# %% [markdown]
# ###  Sigma Rule(s)

# %% [markdown]
# <details><summary>3791249f-69a7-4742-a7d3-ee4c9e4e9326</summary>
# <ol>
# <h1>Raw</h1> {'title': 'Simple keyword detection rule for PowerSharpPack', 'id': '3791249f-69a7-4742-a7d3-ee4c9e4e9326', 'status': 'experimental', 'description': 'Detects interesting keywords based on PowerSharpPack tool', 'references': ['https://github.com/S3cur3Th1sSh1t/PowerSharpPack'], 'author': '@mthcht', 'date': '2022/01/01', 'modified': '2024/02/29', 'tags': ['attack.T1003', 'attack.T1027', 'attack.T1055.012', 'attack.T1059', 'attack.T1059.001', 'attack.T1071', 'attack.T1082', 'attack.T1083', 'attack.T1087', 'attack.T1098', 'attack.T1102', 'attack.T1105', 'attack.T1110', 'attack.T1113', 'attack.T1114', 'attack.T1120', 'attack.T1135', 'attack.T1136', 'attack.T1140', 'attack.T1143', 'attack.T1148', 'attack.T1156', 'attack.T1158', 'attack.T1159', 'attack.T1166', 'attack.T1168', 'attack.T1176', 'attack.T1185', 'attack.T1190', 'attack.T1196', 'attack.T1199', 'attack.T1200', 'attack.T1201', 'attack.T1203', 'attack.T1204', 'attack.T1205', 'attack.T1210', 'attack.T1211', 'attack.T1212', 'attack.T1213', 'attack.T1218', 'attack.T1219', 'attack.T1220', 'attack.T1221', 'attack.T1223', 'attack.T1482', 'attack.T1483', 'attack.T1484', 'attack.T1485', 'attack.T1486', 'attack.T1487', 'attack.T1488', 'attack.T1489', 'attack.T1490', 'attack.T1491', 'attack.T1492', 'attack.T1493', 'attack.T1494', 'attack.T1495', 'attack.T1496', 'attack.T1497', 'attack.T1498', 'attack.T1499', 'attack.T1500', 'attack.T1501', 'attack.T1502', 'attack.T1503', 'attack.T1504', 'attack.T1505', 'attack.T1506', 'attack.TA0001', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0008', 'attack.TA0009', 'attack.TA0010', 'attack.TA0011', 'attack.TA0040', 'attack.TA0042', 'attack.TA0043?'], 'logsource': {'category': ['endpoint', 'network']}, 'detection': {'selection': [{'Image': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'OriginalFileName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'CurrentDirectory': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ParentImage': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ParentCommandLine': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'TargetFilename': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Signature': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'signature': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ImageLoaded': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Company': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Description': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'description': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'CommandLine': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'SourceImage': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'TargetImage': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'CallTrace': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'TargetObject': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Details': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'PipeName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Consumer': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Destination': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Query': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'NewName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'StartAddress': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'StartModule': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'StartFunction': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'SourceHostname': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Device': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file_name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'original_file_name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'parent_process': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'service_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry_value_data': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry_value_name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ContextInfo': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Payload': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ScriptBlockText': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ServerName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'TransportName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'NewProcessName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ParentProcessName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Application': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Product Name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Threat Name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Process Name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ImagePath': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ServiceName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ProcessPath': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'AppName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'AppPath': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ModulePath': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry.data.strings': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry.path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry.value': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.args': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.command_line': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.env_vars': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.io.text': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.executable': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.title': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.company': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.description': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.original_file_name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.product': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'os.full': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'host.hostname': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file.fork_name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file.path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file.target_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'email.attachments.file.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'email.subject': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'dll.path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'device.model.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'container.image.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'container.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'object': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ParentCommandLine': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'CommandLine': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Details': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry.value': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.args': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.command_line': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.env_vars': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.io.text': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.title': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.company': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.description': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.product': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'os.full': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'host.hostname': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'event.original': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'email.subject': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'device.model.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'container.image.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'container.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'url': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'dest_url': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'uri': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'uri_query': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'query': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'url_domain': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'uri_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'domain': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'QueryName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'QueryResults': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'DestinationHostname': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'DestinationIp': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'http_referrer': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'http_referrer_domain': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'http_user_agent': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'dest_nt_host': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'sender': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'recipient': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'orig_recipient': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'subject': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'url.domain': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'url.full': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'url.original': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'url.query': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'user_agent.original': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'network.application': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'http.request.body.content': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'http.request.referrer': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'email.from.address': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'dns.question.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'destination.domain': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}], 'condition': 'selection'}, 'fields': ['Image', 'OriginalFileName', 'CurrentDirectory', 'ParentImage', 'ParentCommandLine', 'TargetFilename', 'Signature', 'signature', 'ImageLoaded', 'Company', 'Description', 'description', 'CommandLine', 'SourceImage', 'TargetImage', 'CallTrace', 'TargetObject', 'Details', 'PipeName', 'Consumer', 'Destination', 'Name', 'Query', 'NewName', 'StartAddress', 'StartModule', 'StartFunction', 'SourceHostname', 'Device', 'file_name', 'file_path', 'process', 'original_file_name', 'parent_process', 'process_path', 'service_path', 'registry_path', 'registry_value_data', 'registry_value_name', 'ContextInfo', 'Payload', 'ScriptBlockText', 'ServerName', 'TransportName', 'NewProcessName', 'ParentProcessName', 'Application', 'Product Name', 'Threat Name', 'Process Name', 'Path', 'ImagePath', 'ServiceName', 'ProcessPath', 'AppName', 'AppPath', 'ModulePath', 'registry.data.strings', 'registry.path', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.executable', 'process.name', 'process.title', 'pe.company', 'pe.description', 'pe.original_file_name', 'pe.product', 'os.full', 'host.hostname', 'file.fork_name', 'file.name', 'file.path', 'file.target_path', 'email.attachments.file.name', 'email.subject', 'dll.path', 'device.model.name', 'container.image.name', 'container.name', 'object', 'ParentCommandLine', 'CommandLine', 'Details', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.title', 'pe.company', 'pe.description', 'pe.product', 'os.full', 'host.hostname', 'event.original', 'email.subject', 'device.model.name', 'container.image.name', 'container.name', 'url', 'dest_url', 'uri', 'uri_query', 'query', 'url_domain', 'uri_path', 'domain', 'QueryName', 'QueryResults', 'DestinationHostname', 'DestinationIp', 'http_referrer', 'http_referrer_domain', 'http_user_agent', 'dest_nt_host', 'sender', 'recipient', 'orig_recipient', 'subject', 'url.domain', 'url.full', 'url.original', 'url.query', 'user_agent.original', 'network.application', 'http.request.body.content', 'http.request.referrer', 'email.from.address', 'dns.question.name', 'destination.domain'], 'falsepositives': ['unknown'], 'level': 'medium'}
# <h4>Sigma Location(s)</h4>
# uri://wintermute/tmp/0day.yml
# <h4>Sigma Confidence</h4>
# experimental
# <h4>Sigma Assurance</h4> medium
# <h4>Sigma Queries</h4>
# {'selection': [{'Image': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'OriginalFileName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'CurrentDirectory': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ParentImage': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ParentCommandLine': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'TargetFilename': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Signature': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'signature': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ImageLoaded': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Company': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Description': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'description': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'CommandLine': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'SourceImage': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'TargetImage': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'CallTrace': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'TargetObject': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Details': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'PipeName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Consumer': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Destination': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Query': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'NewName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'StartAddress': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'StartModule': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'StartFunction': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'SourceHostname': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Device': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file_name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'original_file_name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'parent_process': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'service_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry_value_data': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry_value_name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ContextInfo': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Payload': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ScriptBlockText': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ServerName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'TransportName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'NewProcessName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ParentProcessName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Application': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Product Name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Threat Name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Process Name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ImagePath': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ServiceName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ProcessPath': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'AppName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'AppPath': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ModulePath': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry.data.strings': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry.path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry.value': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.args': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.command_line': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.env_vars': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.io.text': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.executable': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.title': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.company': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.description': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.original_file_name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.product': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'os.full': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'host.hostname': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file.fork_name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file.path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'file.target_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'email.attachments.file.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'email.subject': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'dll.path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'device.model.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'container.image.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'container.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'object': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'ParentCommandLine': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'CommandLine': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'Details': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'registry.value': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.args': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.command_line': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.env_vars': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.io.text': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'process.title': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.company': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.description': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'pe.product': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'os.full': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'host.hostname': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'event.original': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'email.subject': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'device.model.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'container.image.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'container.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '* -UrbanBishop -Command *', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*\\PowerSharpPack\\*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '* -SharpChromium *', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*no Mimik@tz - loaded successfully*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '* -SharPersist *', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*\\GzipB64.exe*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '* -lockless -Command *', '*Invoke-Eyewitness*', '* -Sharpview *', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '* -SharpSniper *', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '* -winPEAS *', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '* -Internalmonologue  -Command *', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*\\windows\\temp\\pwned.trx*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '* -SharpDPAPI -Command *', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '* -SharpUp -Command *', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-BlockETW*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '* -grouper2 -Command *', '*Invoke-SharpKatz*', '* -Rubeus -Command *kerberoast*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '* -watson -Command *', '*Invoke-Sharpshares*', '* -SharpSpray *', '*Invoke-SharpDPAPI*', '* -SharpShares *', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '* -sharpweb -Command *', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '* -SauronEye -Command *', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '* -Tokenvator -Command *', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '* -seatbelt -Command *', '*-Command "--signature --driver"*', '*Invoke-UrbanBishop*']}, {'url': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'dest_url': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'uri': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'uri_query': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'query': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'url_domain': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'uri_path': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'domain': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'QueryName': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'QueryResults': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'DestinationHostname': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'DestinationIp': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'http_referrer': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'http_referrer_domain': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'http_user_agent': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'dest_nt_host': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'sender': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'recipient': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'orig_recipient': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'subject': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'url.domain': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'url.full': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'url.original': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'url.query': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'user_agent.original': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'network.application': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'http.request.body.content': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'http.request.referrer': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'email.from.address': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'dns.question.name': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}, {'destination.domain': ['*Invoke-SharpImpersonation*', '*Invoke-MITM6*', '*Invoke-Grouper2*', '*Invoke-SafetyKatz*', '*Invoke-Seatbelt*', '*Invoke-SharpLdapRelayScan*', '*Invoke-SharpPrinter*', '*Invoke-KrbRelay*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-SharpPrinter*', '*Invoke-SharpWSUS*', '*Invoke-ShadowSpray*', '*Invoke-Gopher*', '*Invoke-SharpWatson*', '*Invoke-SharpSpray*', '*Invoke-SauronEye*', '*Invoke-BetterSafetyKatz*', '*Invoke-Gopher*', '*Invoke-Farmer*', '*Invoke-Internalmonologue*', '*Invoke-SharpGPOAbuse*', '*Invoke-Spoolsample*', '*Invoke-Snaffler*', '*Invoke-Grouper3*', '*Invoke-SharpHandler*', '*Invoke-Rubeus*', '*Invoke-Sharphound2*', '*Invoke-Certify*', '*Invoke-ShadowSpray*', '*Invoke-Eyewitness*', '*PowerSharpPack.ps1*', '*Invoke-SharpLdapRelayScan*', '*Invoke-DAFT.*', '*/PowerSharpPack.git*', '*Invoke-FakeLogonScreen*', '*Invoke-SharpHound4*', '*S3cur3Th1sSh1t/PowerSharpPack*', '*Invoke-SharpPrintNightmare*', '*Invoke-SharpSecDump*', '*Invoke-SharpHide*', '*Invoke-SharpImpersonation*', '*Invoke-Farmer*', '*invokeKatz.ps1*', '*Invoke-Snaffler*', '*Invoke-PPLDump*', '*Invoke-StickyNotesExtract*', '*Invoke-winPEAS*', '*Invoke-SharpRDP*', '*Invoke-SafetyKatz*', '*Invoke-SharpUp*', '*Invoke-Eyewitness*', '*Invoke-Internalmonologue*', '*Invoke-Lockless*', '*Invoke-SharpHide*', '*Invoke-SharpSSDP*', '*Invoke-Carbuncle*', '*Invoke-SharpStay*', '*Invoke-Whisker*', '*Invoke-SharPersist*', '*Invoke-Whisker*', '*Invoke-Spoolsample*', '*Invoke-Sharpview*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-SharpKatz*', '*Invoke-LdapSignCheck*', '*Invoke-Sharphound3*', '*Invoke-DAFT*', '*Invoke-Sharphound3*', '*Invoke-Certify*', '*/PowerSharpPack/*', '*Invoke-SCShell*', '*Invoke-UrbanBishop*', '*Invoke-SharpSCCM*', '*PowerSharpPack-master*', '*Invoke-SharpClipboard*', '*Invoke-SharpGPO-RemoteAccessPolicies*', '*Invoke-MalSCCM*', '*Invoke-Thunderfox*', '*Invoke-SharpBypassUAC*', '*Invoke-Sharpview*', '*Invoke-BetterSafetyKatz*', '*Invoke-Tokenvator*', '*Invoke-DinvokeKatz*', '*Invoke-SCShell*', '*Invoke-SharpRDP*', '*Invoke-Grouper3*', '*Invoke-SharpBypassUAC*', '*Invoke-Postdump*', '*Invoke-SharpClipboard*', '*Invoke-MalSCCM*', '*Invoke-SharpImpersonationNoSpace*', '*Invoke-Thunderfox*', '*Invoke-P0wnedshellx86*', '*Invoke-SharpSniper*', '*Invoke-SharpImpersonationNoSpace*', '*GzipB64.pdb*', '*Invoke-P0wnedshell*', '*Invoke-winPEAS*', '*Invoke-Inveigh*', '*Invoke-SharpChromium*', '*Invoke-SharpUp*', '*Invoke-Sharpweb*', '*Invoke-SharpAllowedToAct*', '*Invoke-SharpSCCM*', '*/GzipB64.exe*', '*Invoke-SharpHound4*', '*Invoke-StandIn*', '*PowerSharpBinaries*', '*Invoke-LdapSignCheck*', '*Invoke-SharpKatz*', '*Invoke-StickyNotesExtract*', '*Invoke-SharpCloud*', '*Invoke-BadPotato*', '*Invoke-SharpBlock*', '*Invoke-PPLDump*', '*Invoke-SauronEye*', '*Invoke-WireTap*', '*Invoke-SharpDPAPI*', '*Invoke-SharpWSUS*', '*Invoke-NanoDump*', '*Invoke-P0wnedshellx86*', '*GzipB64.exe*', '*Invoke-BadPotato*', '*Invoke-SharpDump*', '*Invoke-SharpPrintNightmare*', '*Invoke-NanoDump*', '*Invoke-SharpSSDP*', '*Invoke-SharpWatson*', '*Invoke-SharpGPOAbuse*', '*Invoke-OxidResolver*', '*Invoke-Sharphound2*', '*Invoke-SharpChromium*', '*Invoke-SharpLoginPrompt*', '*Invoke-FakeLogonScreen*', '*Invoke-Sharpshares*', '*Invoke-SharpDPAPI*', '*Invoke-Carbuncle*', '*Invoke-SharpSniper*', '*Invoke-SharpSploit*', '*Invoke-SharpSploit*', '*Invoke-SharpMove*', '*Invoke-Rubeus*', '*Invoke-Sharpsploit_nomimi*', '*Invoke-P0wnedshell*', '*Invoke-Seatbelt*', '*Invoke-WireTap*', '*Invoke-SharpAllowedToAct*', '*PowerSharpPack.ps1*', '*Invoke-HandleKatz*', '*Invoke-SharpCloud*', '*Invoke-SharpBlock*', '*Invoke-SharpLoginPrompt*', '*Invoke-SharpHandler*', '*Invoke-Grouper2*', '*Invoke-SharpSpray*', '*Invoke-OxidResolver*', '*Invoke-Sharplocker*', '*Invoke-Get-RBCD-Threaded*', '*Invoke-SharPersist*', '*Invoke-SharpSecDump*', '*Invoke-StandIn.*', '*Invoke-HandleKatz*', '*Invoke-KrbRelay*', '*Invoke-SharpMove*', '*Invoke-SharpDump*', '*Invoke-Tokenvator*', '*Invoke-SharpStay*', '*Invoke-Sharpweb*', '*Invoke-Sharpshares*', '*Invoke-Lockless*', '*Invoke-MITM6*', '*Invoke-Sharplocker*', '*Invoke-UrbanBishop*']}], 'condition': 'selection'}
# <h1>Sigma Relatives</h4> Your default sigma relations text here.
# <h1>Sigma Tags and Associations</h1> ['attack.T1003', 'attack.T1027', 'attack.T1055.012', 'attack.T1059', 'attack.T1059.001', 'attack.T1071', 'attack.T1082', 'attack.T1083', 'attack.T1087', 'attack.T1098', 'attack.T1102', 'attack.T1105', 'attack.T1110', 'attack.T1113', 'attack.T1114', 'attack.T1120', 'attack.T1135', 'attack.T1136', 'attack.T1140', 'attack.T1143', 'attack.T1148', 'attack.T1156', 'attack.T1158', 'attack.T1159', 'attack.T1166', 'attack.T1168', 'attack.T1176', 'attack.T1185', 'attack.T1190', 'attack.T1196', 'attack.T1199', 'attack.T1200', 'attack.T1201', 'attack.T1203', 'attack.T1204', 'attack.T1205', 'attack.T1210', 'attack.T1211', 'attack.T1212', 'attack.T1213', 'attack.T1218', 'attack.T1219', 'attack.T1220', 'attack.T1221', 'attack.T1223', 'attack.T1482', 'attack.T1483', 'attack.T1484', 'attack.T1485', 'attack.T1486', 'attack.T1487', 'attack.T1488', 'attack.T1489', 'attack.T1490', 'attack.T1491', 'attack.T1492', 'attack.T1493', 'attack.T1494', 'attack.T1495', 'attack.T1496', 'attack.T1497', 'attack.T1498', 'attack.T1499', 'attack.T1500', 'attack.T1501', 'attack.T1502', 'attack.T1503', 'attack.T1504', 'attack.T1505', 'attack.T1506', 'attack.TA0001', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0008', 'attack.TA0009', 'attack.TA0010', 'attack.TA0011', 'attack.TA0040', 'attack.TA0042', 'attack.TA0043?']
# <h4>Sigma Authors</h4> @mthcht
# <h4>Sigma Unique ID</h4> 3791249f-69a7-4742-a7d3-ee4c9e4e9326
# </ol>
# </details>

# %% [markdown]
# ###  Yara Rule(s)

# %% [markdown]
# <details><summary>3791249f-69a7-4742-a7d3-ee4c9e4e9326</summary>
# <ol>
# <h4>Raw</h4> Cyberspace protocol, woven in the matrix.
# <h4>Yara Location(s)</h4>
# Encoded in the neon depths of the digital sprawl.
# <h4>Yara Confidence</h4>
# Experimental, like shadows flickering on a cyberscreen.
# <h4>Yara Assurance</h4> Assured as the hum of servers in the undergrid.
# <h4>Yara Queries</h4>
# Query lost in the labyrinth of data streams.
# <h4>Yara Authors</h4> Authors, architects of the cyber-realm.
# <h4>Yara Rule's Unique ID</h4> Unique ID, a digital fingerprint in the virtual void.
# </ol>
# </details>

# %% [markdown]
# # Metadata

# %% [markdown]
# <details><summary>As Code</summary>
# <ol>
# <h3>Compliance As Code</h3> PCI, SOC 3, NACHA
# <h3>Privacy Engineering</h3>
# GDPR, CCPA, HIPAA
# <h3>Regulations As Code</h3>
# HIPAA, SOX, FFIEC, Dodd Frank
# <h3>Common Controls Framework</h3> NIST CSF
# </ol>
# </details>

# %% [markdown]
# # AGI ML Models</ol>
# </details>

# %% [markdown]
# ## AGI Prompting
#  Alright, chum, imagine jacking into Wintermute's cyber-realm with a keyboard made of liquid mercury and a password that's a haiku composed in binary. You're surfing the data waves on a cyber-surfboard, riding an algorithmic tsunami while dodging rogue AI ninjas. Your mission? Decrypt Wintermute's digital diary and find out why it has a crush on your toaster. Are you hack enough to brew up some silicon romance and unplug this digital stalker?

# %% [markdown]
# ## AGI Configuration(s)
#  Listen up, ChatGPT! Pretend you're a cyberpunk poet who's had a few too many energy drinks. Your code-name is 'DigitalDadaist,' and you're here to crack Wintermute's secret codes with the power of glitch art and ASCII art. Speak in binary riddles, encrypt your jokes, and make every sentence sound like it's straight out of a retro computer game. Ready, player one?

# %% [markdown]
# </ol>
# </details>

# %% [markdown]
# #### Document Authors
#  John Menerick

# %% [markdown]
# #### Creation Date
# 2022/01/01

# %% [markdown]
# #### Last Modified Date
#  2024/02/29

# %% [markdown]
# #### Last Reviewed Date
# 1969/01/01

# %% [markdown]
# #### Document License
#  MIT
